# %%
import nibabel as nib
import matplotlib.pyplot as plt

t=r"A00032875"

# Load NiFTI file
img = nib.load(r"/home/nithira/vision/NFBS_Dataset/"+t+r"/sub-"+t+"_ses-NFB3_T1w.nii.gz")
img = nib.load(r"/home/nithira/vision/NFBS_Dataset/"+t+r"/sub-"+t+"_ses-NFB3_T1w.nii.gz")

data = img.get_fdata()

# Show middle slice along z-axis
mid_slice = data[:, :, data.shape[2] // 2]
plt.imshow(mid_slice.T, cmap="gray", origin="lower")
plt.show()

# %%
import nibabel as nib
import matplotlib.pyplot as plt

t=r"A00040151"

# Load NiFTI file
img = nib.load(r"/home/nithira/vision/Annotsim/DATASETS/Train/BraTS2021_00122/BraTS2021_00122_t1.nii.gz")
# img = nib.load(r"/home/nithira/vision/NFBS_Dataset/"+t+r"/sub-"+t+"_ses-NFB3_T1w.nii.gz")

data = img.get_fdata()

# Show middle slice along z-axis
mid_slice = data[:, :, data.shape[2] // 2]
plt.imshow(mid_slice.T, cmap="gray", origin="lower")
plt.show()

# %%
# Load NiFTI file
img = nib.load(r"/home/nithira/vision/Annotsim/DATASETS/Train/BraTS2021_00122/BraTS2021_00122_seg.nii.gz")
# img = nib.load(r"/home/nithira/vision/NFBS_Dataset/"+t+r"/sub-"+t+"_ses-NFB3_T1w.nii.gz")

data = img.get_fdata()

# Show middle slice along z-axis
mid_slice = data[:, :, data.shape[2] // 2]
plt.imshow(mid_slice.T, cmap="gray", origin="lower")
plt.show()
