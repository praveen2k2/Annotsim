# %%
import nibabel as nib
import matplotlib.pyplot as plt

# Load NiFTI file
img = nib.load(r"/home/nithira/vision/NFBS_Dataset/A00028185/sub-A00028185_ses-NFB3_T1w_brain.nii.gz")
data = img.get_fdata()

# Show middle slice along z-axis
mid_slice = data[:, :, data.shape[2] // 2]
plt.imshow(mid_slice.T, cmap="gray", origin="lower")
plt.show()
