# %%
import torch
import os
import os
from random import randint

import cv2
import nibabel
import nibabel as nib
import numpy as np
import torch
from matplotlib import animation
from torch.utils.data import Dataset
from torchvision import datasets, transforms
import imageio
import os
from PIL import Image
from torchvision import transforms
import pandas as pd
import random
from scipy import ndimage
import mat73
import h5py
import matplotlib.pyplot as plt

# %%
p = r"C:\Users\Admin\Dropbox\PC\Documents\Anomaly Detection\AnoDDPM\DATASETS\Brats2020\BraTS2020_training_data\content\data\volume_1_slice_3.h5"

# %%
image = cv2.imread(r"DATASETS/CheNemonia/chest_xray/train\NORMAL/IM-0182-0001.jpeg")
colormap = plt.get_cmap('inferno')
heatmap = (colormap(image) * 2**16).astype(np.uint16)[:,:,:3]
heatmap = cv2.cvtColor(heatmap, cv2.COLOR_RGB2BGR)

# %%
plt.imshow(image,  cmap='hot')
